# %%
# !dir
# Out:
# lost+found		       Untitled2.ipynb	Untitled6.ipynb
# shared			       Untitled3.ipynb	Untitled7.ipynb
# Testing\ remote\ access.ipynb  Untitled4.ipynb	Untitled.ipynb
# Untitled1.ipynb		       Untitled5.ipynb

# %%
C:/Users\xpaanf\advanced_data_analysis\2021

# %%
1+1
# Out:
# 2

# %%
x=2.1

# %%
x
# Out:
# 2.1

# %%
print(x)
# Out:
# 1

# %%
x, type(x)
# Out:
# (2.1, float)

# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
