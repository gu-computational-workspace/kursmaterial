# %%
# !dir
# Out:
# README.md
# Tutorial\ 1\ Introduction\ to\ Python.ipynb
# Tutorial\ 2\ strings\ and\ ways\ to\ store\ data.ipynb
# Tutorial\ 3\ Pandas.ipynb
# Tutorial\ 4\ and\ 5\ Pivot\ tables\ plots\ EOQ\ calc.ipynb
# complete_dataset.csv
# df_top_prod.xlsx
# required_modules.ipynb

# %%
1+1
# Out:
# 2

# %%
x=2.1

# %%
x
# Out:
# 2.1

# %%
print(x)
# Out:
# 2.1

# %%
x, type(x)
# Out:
# (2.1, float)

# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
