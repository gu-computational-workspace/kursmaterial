# %%
import random

# %% [markdown]
# # DO NOT! change the random seed!
# # <b><u>DO NOT RE-RUN this notebook. </u></b>
# You will get a different list and you will use the wrong set of ticker.

# %%
random.seed(42)

# %%
import os

# Define the folder path
folder_path = "transcripts"

# Get all files in the folder
all_files = os.listdir(folder_path)

# Create a list of all files that end with '.p'
tickers = [file[:-2] for file in all_files if file.endswith('.p')]

# Print the list of file names without '.p'
print(len(tickers))
tickers
# Out:
# 89
# ['ABT',
#  'AMGN',
#  'ABBV',
#  'ASML',
#  'AMD',
#  'ADBE',
#  'AMT',
#  'BA',
#  'AZN',
#  'AXP',
#  'BMY',
#  'EBAY',
#  'BAC',
#  'IBM',
#  'EL',
#  'C',
#  'BLK',
#  'MCD',
#  'HD',
#  'GS',
#  'JNJ',
#  'ACN',
#  'F',
#  'AMZN',
#  'GOOG',
#  'FB',
#  'INTC',
#  'DUK',
#  'LLY',
#  'CVS',
#  'BX',
#  'BKNG',
#  'GM',
#  'LMT',
#  'LOW',
#  'FDX',
#  'CHTR',
#  'PFE',
#  'UNH',
#  'DIS',
#  'COST',
#  'PG',
#  'PM',
#  'CMCSA',
#  'MDT',
#  'NVDA',
#  'HON',
#  'MA',
#  'MS',
#  'INTU',
#  'MSFT',
#  'TGT',
#  'DHR',
#  'MCO',
#  'KO',
#  'CVX',
#  'CRM',
#  'SE',
#  'CSCO',
#  'TMUS',
#  'TSLA',
#  'MRK',
#  'NFLX',
#  'SNY',
#  'NVS',
#  'JPM',
#  'TD',
#  'NVO',
#  'QCOM',
#  'TMO',
#  'ORCL',
#  'ISRG',
#  'MET',
#  'PEP',
#  'AAPL',
#  'SBUX',
#  'TSM',
#  'TXN',
#  'NKE',
#  'UPS',
#  'SAP',
#  'T',
#  'RY',
#  'XOM',
#  'V',
#  'UNP',
#  'WMT',
#  'VZ',
#  'WFC']

# %%
print(tickers)
# Out:
# ['ABT', 'AMGN', 'ABBV', 'ASML', 'AMD', 'ADBE', 'AMT', 'BA', 'AZN', 'AXP', 'BMY', 'EBAY', 'BAC', 'IBM', 'EL', 'C', 'BLK', 'MCD', 'HD', 'GS', 'JNJ', 'ACN', 'F', 'AMZN', 'GOOG', 'FB', 'INTC', 'DUK', 'LLY', 'CVS', 'BX', 'BKNG', 'GM', 'LMT', 'LOW', 'FDX', 'CHTR', 'PFE', 'UNH', 'DIS', 'COST', 'PG', 'PM', 'CMCSA', 'MDT', 'NVDA', 'HON', 'MA', 'MS', 'INTU', 'MSFT', 'TGT', 'DHR', 'MCO', 'KO', 'CVX', 'CRM', 'SE', 'CSCO', 'TMUS', 'TSLA', 'MRK', 'NFLX', 'SNY', 'NVS', 'JPM', 'TD', 'NVO', 'QCOM', 'TMO', 'ORCL', 'ISRG', 'MET', 'PEP', 'AAPL', 'SBUX', 'TSM', 'TXN', 'NKE', 'UPS', 'SAP', 'T', 'RY', 'XOM', 'V', 'UNP', 'WMT', 'VZ', 'WFC']

# %%
students_ids = [
 'gusabuchu',
 'gusalwis',
 'gusalijna',
 'gusandsaep',
 'gusandsiak',
 'gusbigso',
 'gusdencaa',
 'gusekmat',
 'gusenthfr',
 'gusfloreju',
 'gusforsste',
 'gusfresai',
 'gusjoelga',
 'gusgarska',
 'gusgastu',
 'gusguserv',
 'gushedeph',
 'gushjeanf',
 'gusinafe',
 'gustimoja',
 'gusjebos',
 'gusjohelgh',
 'gusjohjofu',
 'gusjonmahb',
 'gusmaheka',
 'guskarlawi',
 'guskaradn',
 'gusmothi',
 'gusmouor',
 'gusnilolaa',
 'gusnilosj',
 'gusnyakst',
 'gusobeah',
 'gusodlfr',
 'gusokahi',
 'gusolhka',
 'gusolsalad',
 'guspethaab',
 'gusrajara',
 'gusranwi',
 'gusrootlo',
 'gusrujij',
 'gussaile',
 'gusternca',
 'gusellti',
 'gusvuysr',
 'gusziywa',
 'guswiknax'
]

# %%
len(students_ids)
# Out:
# 48

# %%
['T', 'EL', 'ASML', 'FDX', 'BKNG', 'LLY', 'MCD', 'IBM', 'TMO', 'EBAY', 'SBUX', 'KO', 'AMD', 'WMT', 'UPS', 'DUK', 'CVS', 'NVS', 'NKE', 'FB', 'MCO', 'XOM', 'SE', 'UNP', 'ABT', 'JNJ', 'MDT', 'PEP', 'ACN', 'RY', 'AXP', 'WFC', 'MS', 'TSLA', 'AMT', 'ADBE', 'GOOG', 'TXN', 'F', 'MSFT', 'UNH', 'BLK', 'ABBV', 'MET', 'LOW', 'BA', 'DHR', 'QCOM', 'JPM', 'HD', 'AMZN', 'CHTR', 'BAC', 'TSM', 'HON', 'VZ', 'DIS', 'PG', 'MRK', 'CMCSA']

# %%
for student in students_ids:
    print(student, 'has ticker:')

    # Get 100 random tickers from the list
    tickers_sample = random.sample(tickers, 60)
    print(tickers_sample)

    print('--------------------------------------------------------------------------------------------------------------------------')
    print()
# Out:
# gusabuchu has ticker:
# ['T', 'EL', 'ASML', 'FDX', 'BKNG', 'LLY', 'MCD', 'IBM', 'TMO', 'EBAY', 'SBUX', 'KO', 'AMD', 'WMT', 'UPS', 'DUK', 'CVS', 'NVS', 'NKE', 'FB', 'MCO', 'XOM', 'SE', 'UNP', 'ABT', 'JNJ', 'MDT', 'PEP', 'ACN', 'RY', 'AXP', 'WFC', 'MS', 'TSLA', 'AMT', 'ADBE', 'GOOG', 'TXN', 'F', 'MSFT', 'UNH', 'BLK', 'ABBV', 'MET', 'LOW', 'BA', 'DHR', 'QCOM', 'JPM', 'HD', 'AMZN', 'CHTR', 'BAC', 'TSM', 'HON', 'VZ', 'DIS', 'PG', 'MRK', 'CMCSA']
# --------------------------------------------------------------------------------------------------------------------------
#
# gusalwis has ticker:
# ...
