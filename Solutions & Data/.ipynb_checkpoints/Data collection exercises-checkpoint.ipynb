# %%
# imports
import numpy as np
import pandas as pd
import pandas_datareader as pdr
import pandas_datareader.data as web
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1

# %%
# Read the CSV file into a DataFrame
fundamentals_df = pd.read_csv('test_data.csv')
fundamentals_df
# Out:
#        datadate  fyearq  fqtr indfmt consol popsrc datafmt   tic      cusip  \
# 0    31/03/2010    2010     2   INDL      C      D     STD  AAPL   37833100
# 1    30/06/2010    2010     3   INDL      C      D     STD  AAPL   37833100
# 2    30/09/2010    2010     4   INDL      C      D     STD  AAPL   37833100
# 3    31/12/2010    2011     1   INDL      C      D     STD  AAPL   37833100
# 4    31/03/2011    2011     2   INDL      C      D     STD  AAPL   37833100
# ..          ...     ...   ...    ...    ...    ...     ...   ...        ...
# 169  30/06/2023    2023     2   INDL      C      D     STD  META  30303M102
# 170  30/09/2023    2023     3   INDL      C      D     STD  META  30303M102
# 171  31/12/2023    2023     4   INDL      C      D     STD  META  30303M102
# 172  31/03/2024    2024     1   INDL      C      D     STD  META  30303M102
# 173  30/06/2024    2024     2   INDL      C      D     STD  META  30303M102
#
#                    conm  ... datacqtr datafqtr     actq      ceqq    dd1q  \
# 0             APPLE INC  ...   2010Q1   2010Q2  32336.0   39348.0     0.0
# 1             APPLE INC  ...   2010Q2   2010Q3  36033.0   43111.0     0.0
# 2             APPLE INC  ...   2010Q3   2010Q4  41678.0   47791.0     0.0
# 3             APPLE INC  ...   2010Q4   2011Q1  43927.0   54666.0     NaN
# 4             APPLE INC  ...   2011Q1   2011Q2  46997.0   61477.0     NaN
# ..                  ...  ...      ...      ...      ...       ...     ...
# 169  META PLATFORMS INC  ...   2023Q2   2023Q2  69560.0  134033.0  1577.0
# 170  META PLATFORMS INC  ...   2023Q3   2023Q3  78378.0  142873.0  1545.0
# 171  META PLATFORMS INC  ...   2023Q4   2023Q4  85365.0  153168.0  1713.0
# 172  META PLATFORMS INC  ...   2024Q1   2024Q1  75330.0  149529.0  1676.0
# 173  META PLATFORMS INC  ...   2024Q2   2024Q2  76431.0  156763.0  1917.0
#
#        dlttq    niq  saleq      cik  costat
# 0        0.0   3074  13499   320193       A
# 1        0.0   3253  15700   320193       A
# 2        0.0   4308  20343   320193       A
# 3        0.0   6004  26741   320193       A
# 4        0.0   5987  24667   320193       A
# ..       ...    ...    ...      ...     ...
# 169  35401.0   7789  32000  1326801       A
# 170  35331.0  11583  34146  1326801       A
# 171  36211.0  14017  40111  1326801       A
# 172  35957.0  12369  36455  1326801       A
# 173  36074.0  13465  39072  1326801       A
#
# [174 rows x 21 columns]

# %%
# Rename the column 'tic' to 'ticker'
fundamentals_df.rename(columns={'tic': 'Ticker'}, inplace=True)
fundamentals_df
# Out:
#        datadate  fyearq  fqtr indfmt consol popsrc datafmt Ticker      cusip  \
# 0    31/03/2010    2010     2   INDL      C      D     STD   AAPL   37833100
# 1    30/06/2010    2010     3   INDL      C      D     STD   AAPL   37833100
# 2    30/09/2010    2010     4   INDL      C      D     STD   AAPL   37833100
# 3    31/12/2010    2011     1   INDL      C      D     STD   AAPL   37833100
# 4    31/03/2011    2011     2   INDL      C      D     STD   AAPL   37833100
# ..          ...     ...   ...    ...    ...    ...     ...    ...        ...
# 169  30/06/2023    2023     2   INDL      C      D     STD   META  30303M102
# 170  30/09/2023    2023     3   INDL      C      D     STD   META  30303M102
# 171  31/12/2023    2023     4   INDL      C      D     STD   META  30303M102
# 172  31/03/2024    2024     1   INDL      C      D     STD   META  30303M102
# 173  30/06/2024    2024     2   INDL      C      D     STD   META  30303M102
#
#                    conm  ... datacqtr datafqtr     actq      ceqq    dd1q  \
# 0             APPLE INC  ...   2010Q1   2010Q2  32336.0   39348.0     0.0
# 1             APPLE INC  ...   2010Q2   2010Q3  36033.0   43111.0     0.0
# 2             APPLE INC  ...   2010Q3   2010Q4  41678.0   47791.0     0.0
# 3             APPLE INC  ...   2010Q4   2011Q1  43927.0   54666.0     NaN
# 4             APPLE INC  ...   2011Q1   2011Q2  46997.0   61477.0     NaN
# ..                  ...  ...      ...      ...      ...       ...     ...
# 169  META PLATFORMS INC  ...   2023Q2   2023Q2  69560.0  134033.0  1577.0
# 170  META PLATFORMS INC  ...   2023Q3   2023Q3  78378.0  142873.0  1545.0
# 171  META PLATFORMS INC  ...   2023Q4   2023Q4  85365.0  153168.0  1713.0
# 172  META PLATFORMS INC  ...   2024Q1   2024Q1  75330.0  149529.0  1676.0
# 173  META PLATFORMS INC  ...   2024Q2   2024Q2  76431.0  156763.0  1917.0
#
#        dlttq    niq  saleq      cik  costat
# 0        0.0   3074  13499   320193       A
# 1        0.0   3253  15700   320193       A
# 2        0.0   4308  20343   320193       A
# 3        0.0   6004  26741   320193       A
# 4        0.0   5987  24667   320193       A
# ..       ...    ...    ...      ...     ...
# 169  35401.0   7789  32000  1326801       A
# 170  35331.0  11583  34146  1326801       A
# 171  36211.0  14017  40111  1326801       A
# 172  35957.0  12369  36455  1326801       A
# 173  36074.0  13465  39072  1326801       A
#
# [174 rows x 21 columns]

# %%
# Convert datadate to datetime
fundamentals_df['datadate'] = pd.to_datetime(fundamentals_df['datadate'])
# Out:
# C:\Users\xpaanf\AppData\Local\Temp\ipykernel_2988\3167226822.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   fundamentals_df['datadate'] = pd.to_datetime(fundamentals_df['datadate'])

# %%
# Rename the column 'tic' to 'ticker' (so the same as in share data)
fundamentals_df.rename(columns={'datadate': 'Date'}, inplace=True)
fundamentals_df
# Out:
#           Date  fyearq  fqtr indfmt consol popsrc datafmt Ticker      cusip  \
# 0   2010-03-31    2010     2   INDL      C      D     STD   AAPL   37833100
# 1   2010-06-30    2010     3   INDL      C      D     STD   AAPL   37833100
# 2   2010-09-30    2010     4   INDL      C      D     STD   AAPL   37833100
# 3   2010-12-31    2011     1   INDL      C      D     STD   AAPL   37833100
# 4   2011-03-31    2011     2   INDL      C      D     STD   AAPL   37833100
# ..         ...     ...   ...    ...    ...    ...     ...    ...        ...
# 169 2023-06-30    2023     2   INDL      C      D     STD   META  30303M102
# 170 2023-09-30    2023     3   INDL      C      D     STD   META  30303M102
# 171 2023-12-31    2023     4   INDL      C      D     STD   META  30303M102
# 172 2024-03-31    2024     1   INDL      C      D     STD   META  30303M102
# 173 2024-06-30    2024     2   INDL      C      D     STD   META  30303M102
#
#                    conm  ... datacqtr datafqtr     actq      ceqq    dd1q  \
# 0             APPLE INC  ...   2010Q1   2010Q2  32336.0   39348.0     0.0
# 1             APPLE INC  ...   2010Q2   2010Q3  36033.0   43111.0     0.0
# 2             APPLE INC  ...   2010Q3   2010Q4  41678.0   47791.0     0.0
# 3             APPLE INC  ...   2010Q4   2011Q1  43927.0   54666.0     NaN
# 4             APPLE INC  ...   2011Q1   2011Q2  46997.0   61477.0     NaN
# ..                  ...  ...      ...      ...      ...       ...     ...
# 169  META PLATFORMS INC  ...   2023Q2   2023Q2  69560.0  134033.0  1577.0
# 170  META PLATFORMS INC  ...   2023Q3   2023Q3  78378.0  142873.0  1545.0
# 171  META PLATFORMS INC  ...   2023Q4   2023Q4  85365.0  153168.0  1713.0
# 172  META PLATFORMS INC  ...   2024Q1   2024Q1  75330.0  149529.0  1676.0
# 173  META PLATFORMS INC  ...   2024Q2   2024Q2  76431.0  156763.0  1917.0
#
#        dlttq    niq  saleq      cik  costat
# 0        0.0   3074  13499   320193       A
# 1        0.0   3253  15700   320193       A
# 2        0.0   4308  20343   320193       A
# 3        0.0   6004  26741   320193       A
# 4        0.0   5987  24667   320193       A
# ..       ...    ...    ...      ...     ...
# 169  35401.0   7789  32000  1326801       A
# 170  35331.0  11583  34146  1326801       A
# 171  36211.0  14017  40111  1326801       A
# 172  35957.0  12369  36455  1326801       A
# 173  36074.0  13465  39072  1326801       A
#
# [174 rows x 21 columns]

# %% [markdown]
# ## Step 2

# %%
import yfinance as yf

# Define the ticker symbols
tickers = ['AAPL', 'IBM', 'META']

# Download historical data for the specified tickers from 2010 onwards
data = yf.download(tickers, start='2010-01-01')

# Reset the index to convert the index (date) into a column
data.reset_index(inplace=True)

# Convert the 'Date' column to date format (removing time information)
data['Date'] = data['Date'].dt.date

# Display the first few rows of the resulting DataFrame
data.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
# Price         Date Adj Close                     Close                   \
# Ticker                  AAPL        IBM META      AAPL         IBM META
# 0       2010-01-04  6.454506  75.353821  NaN  7.643214  126.625237  NaN
# 1       2010-01-05  6.465665  74.443504  NaN  7.656429  125.095604  NaN
# 2       2010-01-06  6.362821  73.959953  NaN  7.534643  124.282982  NaN
# 3       2010-01-07  6.351056  73.703934  NaN  7.520714  123.852776  NaN
# 4       2010-01-08  6.393281  74.443504  NaN  7.570714  125.095604  NaN
#
# Price       High                        Low                       Open  \
# Ticker      AAPL         IBM META      AAPL         IBM META      AAPL
# 0       7.660714  127.122368  NaN  7.585000  125.095604  NaN  7.622500
# 1       7.699643  126.051628  NaN  7.616071  124.378586  NaN  7.664286
# 2       7.686786  125.707458  NaN  7.526786  124.101341  NaN  7.656429
# 3       7.571429  124.521988  NaN  7.466071  123.240921  NaN  7.562500
# 4       7.571429  125.162521  NaN  7.466429  123.374763  NaN  7.510714
#
# Price                       Volume
# Ticker         IBM META       AAPL      IBM META
# 0       125.411087  NaN  493729600  6438444  NaN
# 1       125.889099  NaN  601904800  7156104  NaN
# 2       124.933075  NaN  552160000  5863144  NaN
# 3       124.158699  NaN  477131200  6109268  NaN
# 4       123.393883  NaN  447610800  4390271  NaN

# %%
# Flatten the MultiIndex columns
data.columns = [' '.join(col).strip() if isinstance(col, tuple) else col for col in data.columns.values]

# Create a separate DataFrame to hold the long format
long_format = pd.DataFrame()

# Loop through each ticker and extract the relevant data
for ticker in tickers:
    ticker_data = data[['Date', f'Adj Close {ticker}', f'Close {ticker}', f'High {ticker}', f'Low {ticker}', f'Volume {ticker}']]
    ticker_data.columns = ['Date', 'Adj Close', 'Close', 'High', 'Low', 'Volume']  # Rename columns to be the same
    ticker_data['Ticker'] = ticker  # Add a new column for the ticker
    long_format = pd.concat([long_format, ticker_data], ignore_index=True)

# Display the first few rows of the resulting DataFrame
long_format.head()
# Out:
# C:\Users\xpaanf\AppData\Local\Temp\ipykernel_2988\2526964929.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Ticker'] = ticker  # Add a new column for the ticker
# C:\Users\xpaanf\AppData\Local\Temp\ipykernel_2988\2526964929.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Ticker'] = ticker  # Add a new column for the ticker
# C:\Users\xpaanf\AppData\Local\Temp\ipykernel_2988\2526964929.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Ticker'] = ticker  # Add a new column for the ticker
#          Date  Adj Close     Close      High       Low       Volume Ticker
# 0  2010-01-04   6.454506  7.643214  7.660714  7.585000  493729600.0   AAPL
# 1  2010-01-05   6.465665  7.656429  7.699643  7.616071  601904800.0   AAPL
# 2  2010-01-06   6.362821  7.534643  7.686786  7.526786  552160000.0   AAPL
# 3  2010-01-07   6.351056  7.520714  7.571429  7.466071  477131200.0   AAPL
# 4  2010-01-08   6.393281  7.570714  7.571429  7.466429  447610800.0   AAPL

# %%
long_format['Date'] = pd.to_datetime(long_format['Date'])

# %%
long_format
# Out:
#             Date   Adj Close       Close        High         Low       Volume  \
# 0     2010-01-04    6.454506    7.643214    7.660714    7.585000  493729600.0
# 1     2010-01-05    6.465665    7.656429    7.699643    7.616071  601904800.0
# 2     2010-01-06    6.362821    7.534643    7.686786    7.526786  552160000.0
# 3     2010-01-07    6.351056    7.520714    7.571429    7.466071  477131200.0
# 4     2010-01-08    6.393281    7.570714    7.571429    7.466429  447610800.0
# ...          ...         ...         ...         ...         ...          ...
# 11152 2024-10-07  584.780029  584.780029  602.950012  584.039978   12014200.0
# 11153 2024-10-08  592.890015  592.890015  593.559998  585.969971    7857400.0
# 11154 2024-10-09  590.510010  590.510010  594.390015  581.609985    9529700.0
# 11155 2024-10-10  583.830017  583.830017  590.229980  582.520020    7740400.0
# 11156 2024-10-11  589.950012  589.950012  591.210022  582.710022    8571300.0
#
#       Ticker
# 0       AAPL
# 1       AAPL
# 2       AAPL
# 3       AAPL
# 4       AAPL
# ...      ...
# 11152   META
# 11153   META
# 11154   META
# 11155   META
# 11156   META
#
# [11157 rows x 7 columns]

# %% [markdown]
# ## Step 3

# %%
# Sort the data in both dataframe before merging
fundamentals_df.sort_values('Date', inplace=True)
long_format.sort_values('Date', inplace=True)

# %%
# Use direction='forward' to get the next available daily data on or after the quarterly date
merged_df = pd.merge_asof(fundamentals_df, long_format, on='Date', by='Ticker', direction='forward')

# %%
merged_df
# Out:
#           Date  fyearq  fqtr indfmt consol popsrc datafmt Ticker      cusip  \
# 0   2010-03-31    2010     2   INDL      C      D     STD   AAPL   37833100
# 1   2010-03-31    2010     1   INDL      C      D     STD    IBM  459200101
# 2   2010-03-31    2010     1   INDL      C      D     STD   META  30303M102
# 3   2010-06-30    2010     3   INDL      C      D     STD   AAPL   37833100
# 4   2010-06-30    2010     2   INDL      C      D     STD    IBM  459200101
# ..         ...     ...   ...    ...    ...    ...     ...    ...        ...
# 169 2024-03-31    2024     2   INDL      C      D     STD   AAPL   37833100
# 170 2024-03-31    2024     1   INDL      C      D     STD    IBM  459200101
# 171 2024-06-30    2024     2   INDL      C      D     STD    IBM  459200101
# 172 2024-06-30    2024     3   INDL      C      D     STD   AAPL   37833100
# 173 2024-06-30    2024     2   INDL      C      D     STD   META  30303M102
#
#                             conm  ...    niq  saleq      cik  costat  \
# 0                      APPLE INC  ...   3074  13499   320193       A
# 1    INTL BUSINESS MACHINES CORP  ...   2601  22857    51143       A
# 2             META PLATFORMS INC  ...     95    345  1326801       A
# 3                      APPLE INC  ...   3253  15700   320193       A
# 4    INTL BUSINESS MACHINES CORP  ...   3386  23724    51143       A
# ..                           ...  ...    ...    ...      ...     ...
# 169                    APPLE INC  ...  23636  90753   320193       A
# 170  INTL BUSINESS MACHINES CORP  ...   1605  14462    51143       A
# 171  INTL BUSINESS MACHINES CORP  ...   1834  15769    51143       A
# 172                    APPLE INC  ...  21448  85777   320193       A
# 173           META PLATFORMS INC  ...  13465  39072  1326801       A
#
#       Adj Close       Close        High         Low       Volume       ROA
# 0      7.087558    8.392857    8.450357    8.373571  430659600.0  0.095064
# 1     73.290634  122.609940  123.087952  122.036331    5130421.0  0.056918
# 2           NaN         NaN         NaN         NaN          NaN       NaN
# 3      7.586102    8.983214    9.213214    8.928929  739452000.0  0.090278
# 4     70.926430  118.049713  119.713196  117.590820    8386828.0  0.075420
# ..          ...         ...         ...         ...          ...       ...
# 169  169.603378  170.029999  171.250000  169.479996   46240500.0  0.184058
# 170  186.334381  189.830002  190.460007  188.520004    2364300.0  0.043778
# 171  173.581818  175.100006  176.460007  173.380005    3321000.0  0.055077
# 172  216.499405  216.750000  217.509995  211.919998   60402900.0  0.170989
# 173  504.199005  504.679993  506.579987  493.170013   10328200.0  0.176172
#
# [174 rows x 27 columns]

# %% [markdown]
# ## Step 4

# %%
# Calculate ROA, handling division by zero (just calculating one as an example)
merged_df['ROA'] = np.where(merged_df['actq'] != 0, merged_df['niq'] / merged_df['actq'], 0)

# %%
merged_df
# Out:
#           Date  fyearq  fqtr indfmt consol popsrc datafmt Ticker      cusip  \
# 0   2010-03-31    2010     2   INDL      C      D     STD   AAPL   37833100
# 1   2010-03-31    2010     1   INDL      C      D     STD    IBM  459200101
# 2   2010-03-31    2010     1   INDL      C      D     STD   META  30303M102
# 3   2010-06-30    2010     3   INDL      C      D     STD   AAPL   37833100
# 4   2010-06-30    2010     2   INDL      C      D     STD    IBM  459200101
# ..         ...     ...   ...    ...    ...    ...     ...    ...        ...
# 169 2024-03-31    2024     2   INDL      C      D     STD   AAPL   37833100
# 170 2024-03-31    2024     1   INDL      C      D     STD    IBM  459200101
# 171 2024-06-30    2024     2   INDL      C      D     STD    IBM  459200101
# 172 2024-06-30    2024     3   INDL      C      D     STD   AAPL   37833100
# 173 2024-06-30    2024     2   INDL      C      D     STD   META  30303M102
#
#                             conm  ...    niq  saleq      cik  costat  \
# 0                      APPLE INC  ...   3074  13499   320193       A
# 1    INTL BUSINESS MACHINES CORP  ...   2601  22857    51143       A
# 2             META PLATFORMS INC  ...     95    345  1326801       A
# 3                      APPLE INC  ...   3253  15700   320193       A
# 4    INTL BUSINESS MACHINES CORP  ...   3386  23724    51143       A
# ..                           ...  ...    ...    ...      ...     ...
# 169                    APPLE INC  ...  23636  90753   320193       A
# 170  INTL BUSINESS MACHINES CORP  ...   1605  14462    51143       A
# 171  INTL BUSINESS MACHINES CORP  ...   1834  15769    51143       A
# 172                    APPLE INC  ...  21448  85777   320193       A
# 173           META PLATFORMS INC  ...  13465  39072  1326801       A
#
#       Adj Close       Close        High         Low       Volume       ROA
# 0      7.087558    8.392857    8.450357    8.373571  430659600.0  0.095064
# 1     73.290634  122.609940  123.087952  122.036331    5130421.0  0.056918
# 2           NaN         NaN         NaN         NaN          NaN       NaN
# 3      7.586102    8.983214    9.213214    8.928929  739452000.0  0.090278
# 4     70.926430  118.049713  119.713196  117.590820    8386828.0  0.075420
# ..          ...         ...         ...         ...          ...       ...
# 169  169.603378  170.029999  171.250000  169.479996   46240500.0  0.184058
# 170  186.334381  189.830002  190.460007  188.520004    2364300.0  0.043778
# 171  173.581818  175.100006  176.460007  173.380005    3321000.0  0.055077
# 172  216.499405  216.750000  217.509995  211.919998   60402900.0  0.170989
# 173  504.199005  504.679993  506.579987  493.170013   10328200.0  0.176172
#
# [174 rows x 27 columns]

# %% [markdown]
# ## Extra Challenge

# %% [markdown]
# ### Correlations

# %%
# Calculate the correlation between 'Adj Close' and 'ROA'
correlation = merged_df['Adj Close'].corr(merged_df['ROA'])

# %%
correlation
# Out:
# 0.14290901125794975

# %% [markdown]
# ### Visualisations

# %%
# Create the scatter plot
plt.figure(figsize=(14, 7))

# Loop through each unique ticker and plot the data
for ticker in merged_df['Ticker'].unique():
    ticker_data = merged_df[merged_df['Ticker'] == ticker]
    plt.scatter(ticker_data['ROA'], ticker_data['Adj Close'], label=ticker, alpha=0.7)

# Adding titles and labels
plt.title('Scatter Plot of ROA vs Adjusted Close by Ticker', fontsize=16)
plt.xlabel('Return on Assets (ROA)', fontsize=12)
plt.ylabel('Adjusted Close Price', fontsize=12)
plt.legend(title='Ticker')
plt.grid()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate the rolling 4-quarter ROA for each ticker
merged_df['Rolling ROA'] = merged_df.groupby('Ticker')['ROA'].rolling(window=4).mean().reset_index(level=0, drop=True)

# %%
merged_df
# Out:
#           Date  fyearq  fqtr indfmt consol popsrc datafmt Ticker      cusip  \
# 0   2010-03-31    2010     2   INDL      C      D     STD   AAPL   37833100
# 1   2010-03-31    2010     1   INDL      C      D     STD    IBM  459200101
# 2   2010-03-31    2010     1   INDL      C      D     STD   META  30303M102
# 3   2010-06-30    2010     3   INDL      C      D     STD   AAPL   37833100
# 4   2010-06-30    2010     2   INDL      C      D     STD    IBM  459200101
# ..         ...     ...   ...    ...    ...    ...     ...    ...        ...
# 169 2024-03-31    2024     2   INDL      C      D     STD   AAPL   37833100
# 170 2024-03-31    2024     1   INDL      C      D     STD    IBM  459200101
# 171 2024-06-30    2024     2   INDL      C      D     STD    IBM  459200101
# 172 2024-06-30    2024     3   INDL      C      D     STD   AAPL   37833100
# 173 2024-06-30    2024     2   INDL      C      D     STD   META  30303M102
#
#                             conm  ...  saleq      cik costat   Adj Close  \
# 0                      APPLE INC  ...  13499   320193      A    7.087558
# 1    INTL BUSINESS MACHINES CORP  ...  22857    51143      A   73.290634
# 2             META PLATFORMS INC  ...    345  1326801      A         NaN
# 3                      APPLE INC  ...  15700   320193      A    7.586102
# 4    INTL BUSINESS MACHINES CORP  ...  23724    51143      A   70.926430
# ..                           ...  ...    ...      ...    ...         ...
# 169                    APPLE INC  ...  90753   320193      A  169.603378
# 170  INTL BUSINESS MACHINES CORP  ...  14462    51143      A  186.334381
# 171  INTL BUSINESS MACHINES CORP  ...  15769    51143      A  173.581818
# 172                    APPLE INC  ...  85777   320193      A  216.499405
# 173           META PLATFORMS INC  ...  39072  1326801      A  504.199005
#
#           Close        High         Low       Volume       ROA  Rolling ROA
# 0      8.392857    8.450357    8.373571  430659600.0  0.095064          NaN
# 1    122.609940  123.087952  122.036331    5130421.0  0.056918          NaN
# 2           NaN         NaN         NaN          NaN       NaN          NaN
# 3      8.983214    9.213214    8.928929  739452000.0  0.090278          NaN
# 4    118.049713  119.713196  117.590820    8386828.0  0.075420          NaN
# ..          ...         ...         ...          ...       ...          ...
# 169  170.029999  171.250000  169.479996   46240500.0  0.184058     0.171051
# 170  189.830002  190.460007  188.520004    2364300.0  0.043778     0.122987
# 171  175.100006  176.460007  173.380005    3321000.0  0.055077     0.111778
# 172  216.750000  217.509995  211.919998   60402900.0  0.170989     0.113476
# 173  504.679993  506.579987  493.170013   10328200.0  0.176172     0.111504
#
# [174 rows x 28 columns]

# %%
# Create the plot
plt.figure(figsize=(14, 7))

# Plot Rolling ROA by Ticker
for ticker in merged_df['Ticker'].unique():
    ticker_data = merged_df[merged_df['Ticker'] == ticker]
    plt.plot(ticker_data['Date'], ticker_data['Rolling ROA'], label=f'Rolling ROA - {ticker}')

# Adding titles and labels
plt.title('Rolling 4-Quarter ROA by Ticker', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Rolling ROA', fontsize=12)
plt.legend()
plt.grid()

# Show the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
