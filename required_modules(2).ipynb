# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.5 MB 4.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.8 MB 78.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 503 kB 111.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 247 kB 104.2 MB/s eta 0:00:01
# ...
# WARNING: Target directory /opt/app-root/src/.local/lib/python3.8/site-packages/six.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /opt/app-root/src/.local/lib/python3.8/site-packages/six-1.16.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /opt/app-root/src/.local/lib/python3.8/site-packages/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /opt/app-root/src/.local/lib/python3.8/site-packages/pytz already exists. Specify --upgrade to force replacement.
# ...

# %%
pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 4.8 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.3 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
#      |████████████████████████████████| 15.8 MB 4.8 MB/s eta 0:00:01
# ...
# WARNING: Target directory /opt/app-root/src/.local/lib/python3.8/site-packages/numpy-1.21.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /opt/app-root/src/.local/lib/python3.8/site-packages/numpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /opt/app-root/src/.local/lib/python3.8/site-packages/numpy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /opt/app-root/src/.local/lib/python3.8/site-packages/bin already exists. Specify --upgrade to force replacement.
# WARNING: You are using pip version 21.1.3; however, version 21.3 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 10.3 MB 4.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 247 kB 121.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.8 MB 96.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 95.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 94.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 67 kB 93.2 MB/s eta 0:00:01
# ...
# WARNING: Target directory /opt/app-root/src/.local/lib/python3.8/site-packages/six.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /opt/app-root/src/.local/lib/python3.8/site-packages/six-1.16.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /opt/app-root/src/.local/lib/python3.8/site-packages/__pycache__ already exists. Specify --upgrade to force replacement.
# ...
