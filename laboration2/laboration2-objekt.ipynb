# %% [markdown]
# # Laboration 2: Att-göra med objekt

# %% [markdown]
# Målet med laborationen är att skapa egna klasser för att hantera saker som behöver göras, en att-göra lista helt enkelt.
#
# Ibland kan det vara bra att ha en organiserad lista över vad som behöver göras och istället för att använda post-it lappar på kylskåpet så ska vi här använda Python!
#
# ## Uppgift
#
# Du skall implementera två klasser: `Todo` och `Todos`.
#
# Klassen `Todo` används för att representera en sak som behöver göras, t.ex "Gå och handla mat". Tänk att detta motsvarar en post-it lapp.
#
# Klassen `Todos` används för att lagra och hantera många saker att göra, dvs många instanser av `Todo`. Tänk att detta motsvarar ditt kylskåp.
#
# Uppgiften går ut på att färdigställa klasserna nedan enligt specifikationerna.
#
# ### Inlämningsformat
# Om ingen annat anges på Canvas så sparar du dina klasser som en separat Pythonfil när du är klar med namnet `laboration2_objekt.py`
#
# **Viktigt:** det är en **.py** fil och inte en notebook som dina klasser ska sparas i.
#
# ### Viktigt
#  * Du har mycket frihet i hur du väljer att implementera detaljerna för hur du lagrar och hanterar data, det viktiga för uppgiften är att du uppfyller beskrivningen för varje metod:
#    * Att namnet på metoden är rätt
#    * Att argumenten kommer i samma ordning
#    * Att eventuella returvärden stämmer
#    * Att formatet på det som visas på skärmen stämmer med beskrivningen eller exempel
#  * Du får bara skapa nya medlemsvariabler i konstruktorn
#  * Du får gärna bygga ut med mer funktionalitet så länge du uppfyller specifikationerna
#
# ### Tips
#  * Titta igenom hela beskrivningen först och välj sedan själv var du vill börja implementera, du kanske t.ex börjar programmera på Todo.show för att få en kännsla för vilka medlemsvariabler du behöver innan du skapar konstruktorn.
#  * En bra datastruktur för todos i Todos klassen underlättar, det finns många möjligheter här men fundera gärna och testa olika varianter: hur skulle det se ut med en lista? med en dictionary? hur kan du välja en datastruktur som underlättar för de operationer som behöver finnas tillgängligt?
#  * Testa dina implementeringar ofta, se cellen längst ned i denna notebook för en början.
#
# För att testa att er kod fungerar använder ni kommandotolken precis på samma sätt som vi gick igenom under introduktionsföreläsningen.
# Dvs. ta upp kommandotolken och skriv `python shared/test_laboration2.py`.

# %%
class Todo:
    # Implementera en konstruktor som skapar de medlemsvariabler som behövs.
    # Argument:
    #    text: En sträng som beskriver vad som behöver göras. T.ex "Handla bananer"
    #    priority: Ett heltal (int) som indikerar prioritet, ett högre tal betyder en viktigare uppgift. 
        
    # Implementera en metod som ändrar på status för en todo
    # Namn: set_status
    # Argument:
    #   done: En boolean som är True om uppgiften är klar, False annars
        
    # Implementera en metod som ändrar prioritet för en todo
    # Namn: set_priority
    # Argument:
    #   priority: Ett heltal (int) som indikerar prioritet, ett högre tal betyder en viktigare uppgift.
        
    # Implementera en metod som returnerar prioriteten för en todo
    # Namn: get_priority
    # Argument: Inga argument
    # Retur: Ett heltal med todo prioritet
        
    # Implementera en metod som skapar en sträng med information om uppgiften. (Denna metod skall alltså inte skriva ut något på skärmen)
    # Namn: show
    # Argument: Inga argument
    # Retur: En sträng som innehåller beskrivande texten, prioritet samt ifall den är klar eller inte.
    #        Du kan själv välja design på strängen men den måste innehålla "done" om uppgiften är klar.
    #        Exempel på returvärden: 
    #          "Gör klart laboration 2 (prio 2) [todo]"
    #          "Gör klart laboration 1 (prio 1) [done]"

# Implementera en klass som hanterar todo's.
class Todos:
    # Implementera en konstruktor som skapar de medlemsvariabler som behövs.
    # Argument: Inga argument
        
    # Implementera en metod som lägger till en todo.
    # Argument:
    #   text: En sträng med text som beskriver vad som behöver göras.
        
    # Implementera en metod som skriver ut alla todo's på skärmen. (På skärmen betyder här alltså som text med hjälp av t.ex funktionen print)
    # Alla todos som har lagts till ska visas i ordning av prioritet, de som har högst prioritet kommer först (högst upp) osv. 
    # Alla todos ska visas tillsammans med ett id (int) som är en unik identifierare för varje todo, dvs alla todos har olika id.
    # Id skall vara det första på en rad och avslutas med ett kolon (t.ex "4: ....")
    # 
    # Namn: print_todos
    # Argument: Inga argument
    # Retur: Inget returvärde
    # 
    # Exempel på vad som visas på skärmen:
    #   1: Gör klart laboration 2 (prio 2) [todo]
    #   2: Gör klart laboration 1 (prio 1) [done]
    #   3: Handla mat (prio 0) [todo]
    #
    # Tips: Använd Task.show du implementerat ovan för att skapa strängen.
            
    # Implementera en metod som skriver ut alla todos som inte är klara.
    # Formatet ska vara exakt samma som för print_tasks.
    # Name: print_not_done
    # Argument: Inga argument
    
    # Implementera en metod som skriver ut alla todos som är klara.
    # Formatet ska vara exakt samma som för print_tasks.
    # Name: print_done
    # Argument: Inga argument
            
    # Implementera en metod som tar bort en todo.
    # Namn: delete_todo
    # Argument:
    #   todo_id: Ett heltal som indikerar vilken todo som ska tas bort. 
    #            Detta id ska motsvara det id som visas på skärmen med print_todos ovan.
    # Retur: En boolean som indikerar ifall en todo togs bort.
    #
    # Om metoden kallas på med ett todo_id som inte finns ska den skriva ut ett felmedellande på skärmen
    
    # Implementera en metod som sätter status för en todo till klar.
    # Namn: set_done
    # Argument:
    #    task_id: Ett heltal som indikerar vilken todo som skall markeras som klar.
    #             Detta id ska motsvara det id som visas på skärmen med print_todos ovan.
    
    # Implementera en metod som sätter prioritet för en todo.
    # Namn: set_priority
    # Argument:
    #    task_id: Ett heltal som indikerar vilken todo som skall uppdateras.
    #    priority: Ett heltal som indikerar prioritet.

# %% [markdown]
# # Exempel på användning
# Testa din implementering ofta, här är en startpunkt!

# %%
todos = Todos()
todos.add_todo("Gå och handla")
todos.add_todo("Betala räkningar")
todos.print_todos()
