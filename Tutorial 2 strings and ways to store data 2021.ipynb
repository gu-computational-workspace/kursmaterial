# %% [markdown]
# ### Strings

# %%
'apple',"apple", '''apple''', """apple"""
# Out:
# ('apple', 'apple', 'apple', 'apple')

# %%
'''
apple
orange'''
# Out:
# '\napple\norange'

# %%
print('''
apple
orange''')
# Out:
# apple
# orange

# %%
'apple'+' and '+'orange'
# Out:
# 'apple and orange'

# %%
'apple'+2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_425/667322892.py in <module>
# ----> 1 'apple'+2
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### Lists, dictionaries, tuples, and sets => Ways to store data in python
# #### Lists (mutable, indexed by position), surrounded by [,]
# #### Tuples (immutable, indexed by key), surrounded by (, )
# #### Dictionaries (mutable, indexed by key), surrounded by {, }
# #### Sets (mutable, not indexed by position), surrounded by {, }

# %% [markdown]
# ### Lists

# %%
x=[1,2,3,4]

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
x[3]
# Out:
# 4

# %%
x[-1]
# Out:
# 4

# %%
x[:2]
# Out:
# [1, 2]

# %%
x[1:3]
# Out:
# [2, 3]

# %%
x[0]=6

# %%
x
# Out:
# [6, 2, 3, 4]

# %% [markdown]
# ### Tuples

# %%
mytuple=(1,'apple',7)

# %%
mytuple
# Out:
# (1, 'apple', 7)

# %% [markdown]
# ### Dictionaries

# %%
mydictionary ={"car":"Volvo", "bike":"Sjösala"}

# %%
mydictionary
# Out:
# {'car': 'Volvo', 'bike': 'Sjösala'}

# %% [markdown]
# ### Sets

# %%
myset= {"volvo","BMW", 'saab'}
